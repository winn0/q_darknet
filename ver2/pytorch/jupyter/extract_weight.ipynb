# %%
#####load quanztized_resnet18
import sys
import time
import random
import os
sys.path.append("..")
from module.layer_fusion_module import *
from module.resnet_module import *
from module.extract_weight_module import *
model_dir = "saved_models"
model_filename = "q_resnet18_cifar10.pt"
fusioned_model_filename = "q_fusioned_resnet18_cifar10.pt"
quantized_model_filename_jit = "q_resnet18_quantized_cifar10.pt"
quantized_model_filename = "q_resnet18_quantized_cifar10.pt"
model_filepath = os.path.join(model_dir, model_filename)
quantized_model_filepath = os.path.join(model_dir, quantized_model_filename)
quantized_model_filepath_jit = os.path.join(model_dir, quantized_model_filename_jit)

def fuse_model(model,model_name):
    fusion_layer_dict= make_fuse_dict(model,model_name)
    for key in fusion_layer_dict:
        for fuse_group in fusion_layer_dict[key]:        
            torch.quantization.fuse_modules(eval(key), [fuse_group], inplace=True) 

num_classes = 10
cuda_device = torch.device("cuda:0")
cpu_device = torch.device("cpu:0")

model = create_model(num_classes=num_classes)
model.to(cpu_device)

quantized_model = QuantizedResNet18(model_fp32=model)

quantization_config = torch.quantization.get_default_qconfig("fbgemm")

quantized_model.qconfig = quantization_config
fuse_model(quantized_model,'quantized_model')
torch.quantization.prepare_qat(quantized_model, inplace=True)
quantized_model.to(cpu_device)    
quantized_model = torch.quantization.convert(quantized_model, inplace=True)
#save_torchscript_model(model=quantized_model, model_dir=model_dir, model_filename=quantized_model_filename_jit)
#save_model(model=quantized_model, model_dir=model_dir, model_filename=quantized_model_filename)
loaded_model=load_model(model=quantized_model, model_filepath=quantized_model_filepath, device='cpu')
loaded_model.eval()
#save each layer weights
# Out:
# C:\Users\win0\Anaconda3\envs\pytorch\lib\site-packages\torch\ao\quantization\observer.py:174: UserWarning: Please use quant_min and quant_max to specify the range for observers.                     reduce_range will be deprecated in a future release of PyTorch.
#   reduce_range will be deprecated in a future release of PyTorch."
# C:\Users\win0\Anaconda3\envs\pytorch\lib\site-packages\torch\ao\quantization\observer.py:1109: UserWarning: must run observer before calling calculate_qparams.                                    Returning default scale and zero point
#   Returning default scale and zero point "
# QuantizedResNet18(
#   (quant): Quantize(scale=tensor([0.0374]), zero_point=tensor([57]), dtype=torch.quint8)
#   (dequant): DeQuantize()
#   (model_fp32): ResNet(
#     (conv1): Sequential(
#       (0): QuantizedConvReLU2d(3, 64, kernel_size=(7, 7), stride=(2, 2), scale=0.06772751361131668, zero_point=0, padding=(3, 3))
#       (1): Identity()
#       (2): Identity()
#       (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     )
#     (conv2_x): Sequential(
#       (0): q_BasicBlock(
#         (residual_function): Sequential(
#           (0): QuantizedConvReLU2d(64, 64, kernel_size=(3, 3), stride=(1, 1), scale=0.04158411920070648, zero_point=0, padding=(1, 1))
#           (1): Identity()
#           (2): Identity()
#           (3): QuantizedConvReLU2d(64, 64, kernel_size=(3, 3), stride=(1, 1), scale=0.05617671459913254, zero_point=0, padding=(1, 1))
#           (4): Identity()
#           (5): Identity()
#         )
#         (shortcut): Sequential()
#         (q_func): QFunctional(
#           scale=0.08903694897890091, zero_point=0
#           (activation_post_process): Identity()
#         )
#         (relu): ReLU()
#       )
#       (1): q_BasicBlock(
#         (residual_function): Sequential(
#           (0): QuantizedConvReLU2d(64, 64, kernel_size=(3, 3), stride=(1, 1), scale=0.03783448040485382, zero_point=0, padding=(1, 1))
#           (1): Identity()
#           (2): Identity()
#           (3): QuantizedConvReLU2d(64, 64, kernel_size=(3, 3), stride=(1, 1), scale=0.09106125682592392, zero_point=0, padding=(1, 1))
#           (4): Identity()
#           (5): Identity()
#         )
#         (shortcut): Sequential()
#         (q_func): QFunctional(
#           scale=0.1190778836607933, zero_point=0
#           (activation_post_process): Identity()
#         )
#         (relu): ReLU()
#       )
#     )
#     (conv3_x): Sequential(
#       (0): q_BasicBlock(
#         (residual_function): Sequential(
#           (0): QuantizedConvReLU2d(64, 128, kernel_size=(3, 3), stride=(2, 2), scale=0.12558266520500183, zero_point=0, padding=(1, 1))
#           (1): Identity()
#           (2): Identity()
#           (3): QuantizedConvReLU2d(128, 128, kernel_size=(3, 3), stride=(1, 1), scale=0.14312444627285004, zero_point=0, padding=(1, 1))
#           (4): Identity()
#           (5): Identity()
#         )
#         (shortcut): Sequential(
#           (0): QuantizedConvReLU2d(64, 128, kernel_size=(1, 1), stride=(2, 2), scale=0.07153952121734619, zero_point=0)
#           (1): Identity()
#           (2): Identity()
#         )
#         (q_func): QFunctional(
#           scale=0.1646302044391632, zero_point=0
#           (activation_post_process): Identity()
#         )
#         (relu): ReLU()
#       )
#       (1): q_BasicBlock(
#         (residual_function): Sequential(
#           (0): QuantizedConvReLU2d(128, 128, kernel_size=(3, 3), stride=(1, 1), scale=0.2887038588523865, zero_point=0, padding=(1, 1))
#           (1): Identity()
#           (2): Identity()
#           (3): QuantizedConvReLU2d(128, 128, kernel_size=(3, 3), stride=(1, 1), scale=0.32326239347457886, zero_point=0, padding=(1, 1))
#           (4): Identity()
#           (5): Identity()
#         )
#         (shortcut): Sequential()
#         (q_func): QFunctional(
#           scale=0.4041467308998108, zero_point=0
#           (activation_post_process): Identity()
#         )
#         (relu): ReLU()
#       )
#     )
#     (conv4_x): Sequential(
#       (0): q_BasicBlock(
#         (residual_function): Sequential(
#           (0): QuantizedConvReLU2d(128, 256, kernel_size=(3, 3), stride=(2, 2), scale=0.2885167896747589, zero_point=0, padding=(1, 1))
#           (1): Identity()
#           (2): Identity()
#           (3): QuantizedConvReLU2d(256, 256, kernel_size=(3, 3), stride=(1, 1), scale=0.3771272301673889, zero_point=0, padding=(1, 1))
#           (4): Identity()
#           (5): Identity()
#         )
#         (shortcut): Sequential(
#           (0): QuantizedConvReLU2d(128, 256, kernel_size=(1, 1), stride=(2, 2), scale=0.2960608899593353, zero_point=0)
#           (1): Identity()
#           (2): Identity()
#         )
#         (q_func): QFunctional(
#           scale=0.5454142093658447, zero_point=0
#           (activation_post_process): Identity()
#         )
#         (relu): ReLU()
#       )
#       (1): q_BasicBlock(
#         (residual_function): Sequential(
#           (0): QuantizedConvReLU2d(256, 256, kernel_size=(3, 3), stride=(1, 1), scale=0.45926547050476074, zero_point=0, padding=(1, 1))
#           (1): Identity()
#           (2): Identity()
#           (3): QuantizedConvReLU2d(256, 256, kernel_size=(3, 3), stride=(1, 1), scale=0.494729220867157, zero_point=0, padding=(1, 1))
#           (4): Identity()
#           (5): Identity()
#         )
#         (shortcut): Sequential()
#         (q_func): QFunctional(
#           scale=0.8001249432563782, zero_point=0
#           (activation_post_process): Identity()
#         )
#         (relu): ReLU()
#       )
#     )
#     (conv5_x): Sequential(
#       (0): q_BasicBlock(
#         (residual_function): Sequential(
#           (0): QuantizedConvReLU2d(256, 512, kernel_size=(3, 3), stride=(2, 2), scale=0.618948757648468, zero_point=0, padding=(1, 1))
#           (1): Identity()
#           (2): Identity()
#           (3): QuantizedConvReLU2d(512, 512, kernel_size=(3, 3), stride=(1, 1), scale=0.02074870467185974, zero_point=0, padding=(1, 1))
#           (4): Identity()
#           (5): Identity()
#         )
#         (shortcut): Sequential(
#           (0): QuantizedConvReLU2d(256, 512, kernel_size=(1, 1), stride=(2, 2), scale=0.03518309071660042, zero_point=0)
#           (1): Identity()
#           (2): Identity()
#         )
#         (q_func): QFunctional(
#           scale=0.03803124651312828, zero_point=0
#           (activation_post_process): Identity()
#         )
#         (relu): ReLU()
#       )
#       (1): q_BasicBlock(
#         (residual_function): Sequential(
#           (0): QuantizedConvReLU2d(512, 512, kernel_size=(3, 3), stride=(1, 1), scale=0.3381911516189575, zero_point=0, padding=(1, 1))
#           (1): Identity()
#           (2): Identity()
#           (3): QuantizedConvReLU2d(512, 512, kernel_size=(3, 3), stride=(1, 1), scale=0.04247899353504181, zero_point=0, padding=(1, 1))
#           (4): Identity()
#           (5): Identity()
#         )
#         (shortcut): Sequential()
#         (q_func): QFunctional(
#           scale=0.059735652059316635, zero_point=0
#           (activation_post_process): Identity()
#         )
#         (relu): ReLU()
#       )
#     )
#     (avg_pool): AdaptiveAvgPool2d(output_size=(1, 1))
#     (fc): QuantizedLinear(in_features=512, out_features=10, scale=0.5353599190711975, zero_point=54, qscheme=torch.per_channel_affine)
#   )
# )

# %%
extract_model=loaded_model
save_list= dict()
save_list=make_default_save_file(save_list)
for parameter_name in extract_model.state_dict():
    print(parameter_name)
    if parameter_name[-6:]=='weight':
        file_name=parameter_name
        save_np_file=extract_model.state_dict()[parameter_name].int_repr().numpy().flatten()
        save_list=save_np_1darray(save_list,file_name,save_np_file)
        file_name=parameter_name+"_per_channel_scales"
        save_np_file=extract_model.state_dict()[parameter_name].q_per_channel_scales().numpy()
        save_list=save_np_1darray(save_list,file_name,save_np_file)
        file_name=parameter_name+"_per_channel_zero_points"
        save_np_file=extract_model.state_dict()[parameter_name].q_per_channel_zero_points().numpy()
        save_list=save_np_1darray(save_list,file_name,save_np_file)
    elif parameter_name[-4:]=='bias':
        file_name=parameter_name
        save_np_file=extract_model.state_dict()[parameter_name].detach().numpy()
        save_list=save_np_1darray(save_list,file_name,save_np_file)
        
    elif parameter_name[-14:]=='_packed_params':
        file_name=parameter_name
        save_np_file=extract_model.state_dict()[parameter_name][0].int_repr().numpy().flatten()
        save_list=save_np_1darray(save_list,file_name,save_np_file)
        file_name=parameter_name+"_per_channel_scales"
        save_np_file=extract_model.state_dict()[parameter_name][0].q_per_channel_scales().numpy()
        save_list=save_np_1darray(save_list,file_name,save_np_file)
        file_name=parameter_name+"_per_channel_zero_points"
        save_np_file=extract_model.state_dict()[parameter_name][0].q_per_channel_zero_points().numpy()
        save_list=save_np_1darray(save_list,file_name,save_np_file)
        file_name=parameter_name+"_bias"
        save_np_file=extract_model.state_dict()[parameter_name][1].detach().numpy()
        save_list=save_np_1darray(save_list,file_name,save_np_file)            
    else:
        print(extract_model.state_dict()[parameter_name])
    #else:
    #    print(model_int8_unfused.state_dict()[parameter_name].numpy())
# Out:
# quant.scale
# tensor([0.0374])
# quant.zero_point
# tensor([57])
# model_fp32.conv1.0.weight
# model_fp32.conv1.0.bias
# model_fp32.conv1.0.scale
# tensor(0.0883)
# model_fp32.conv1.0.zero_point
# tensor(0)
# model_fp32.conv2_x.0.residual_function.0.weight
# model_fp32.conv2_x.0.residual_function.0.bias
# model_fp32.conv2_x.0.residual_function.0.scale
# tensor(0.0313)
# model_fp32.conv2_x.0.residual_function.0.zero_point
# tensor(0)
# model_fp32.conv2_x.0.residual_function.3.weight
# model_fp32.conv2_x.0.residual_function.3.bias
# model_fp32.conv2_x.0.residual_function.3.scale
# tensor(0.0772)
# model_fp32.conv2_x.0.residual_function.3.zero_point
# tensor(68)
# model_fp32.conv2_x.1.residual_function.0.weight
# model_fp32.conv2_x.1.residual_function.0.bias
# model_fp32.conv2_x.1.residual_function.0.scale
# tensor(0.0376)
# model_fp32.conv2_x.1.residual_function.0.zero_point
# tensor(0)
# model_fp32.conv2_x.1.residual_function.3.weight
# model_fp32.conv2_x.1.residual_function.3.bias
# model_fp32.conv2_x.1.residual_function.3.scale
# tensor(0.1420)
# model_fp32.conv2_x.1.residual_function.3.zero_point
# tensor(75)
# model_fp32.conv3_x.0.residual_function.0.weight
# model_fp32.conv3_x.0.residual_function.0.bias
# model_fp32.conv3_x.0.residual_function.0.scale
# tensor(0.0448)
# model_fp32.conv3_x.0.residual_function.0.zero_point
# tensor(0)
# model_fp32.conv3_x.0.residual_function.3.weight
# model_fp32.conv3_x.0.residual_function.3.bias
# model_fp32.conv3_x.0.residual_function.3.scale
# tensor(0.1405)
# model_fp32.conv3_x.0.residual_function.3.zero_point
# tensor(65)
# model_fp32.conv3_x.0.shortcut.0.weight
# model_fp32.conv3_x.0.shortcut.0.bias
# model_fp32.conv3_x.0.shortcut.0.scale
# tensor(0.0489)
# model_fp32.conv3_x.0.shortcut.0.zero_point
# tensor(0)
# model_fp32.conv3_x.1.residual_function.0.weight
# model_fp32.conv3_x.1.residual_function.0.bias
# model_fp32.conv3_x.1.residual_function.0.scale
# tensor(0.1000)
# model_fp32.conv3_x.1.residual_function.0.zero_point
# tensor(0)
# model_fp32.conv3_x.1.residual_function.3.weight
# model_fp32.conv3_x.1.residual_function.3.bias
# model_fp32.conv3_x.1.residual_function.3.scale
# tensor(0.4939)
# model_fp32.conv3_x.1.residual_function.3.zero_point
# tensor(65)
# model_fp32.conv4_x.0.residual_function.0.weight
# model_fp32.conv4_x.0.residual_function.0.bias
# model_fp32.conv4_x.0.residual_function.0.scale
# tensor(0.2743)
# model_fp32.conv4_x.0.residual_function.0.zero_point
# tensor(0)
# model_fp32.conv4_x.0.residual_function.3.weight
# model_fp32.conv4_x.0.residual_function.3.bias
# model_fp32.conv4_x.0.residual_function.3.scale
# tensor(0.6802)
# model_fp32.conv4_x.0.residual_function.3.zero_point
# tensor(58)
# model_fp32.conv4_x.0.shortcut.0.weight
# model_fp32.conv4_x.0.shortcut.0.bias
# model_fp32.conv4_x.0.shortcut.0.scale
# tensor(0.1994)
# model_fp32.conv4_x.0.shortcut.0.zero_point
# tensor(0)
# model_fp32.conv4_x.1.residual_function.0.weight
# model_fp32.conv4_x.1.residual_function.0.bias
# model_fp32.conv4_x.1.residual_function.0.scale
# tensor(0.4282)
# model_fp32.conv4_x.1.residual_function.0.zero_point
# tensor(0)
# model_fp32.conv4_x.1.residual_function.3.weight
# model_fp32.conv4_x.1.residual_function.3.bias
# model_fp32.conv4_x.1.residual_function.3.scale
# tensor(0.8978)
# model_fp32.conv4_x.1.residual_function.3.zero_point
# tensor(70)
# model_fp32.conv5_x.0.residual_function.0.weight
# model_fp32.conv5_x.0.residual_function.0.bias
# model_fp32.conv5_x.0.residual_function.0.scale
# tensor(0.4506)
# model_fp32.conv5_x.0.residual_function.0.zero_point
# tensor(0)
# model_fp32.conv5_x.0.residual_function.3.weight
# model_fp32.conv5_x.0.residual_function.3.bias
# model_fp32.conv5_x.0.residual_function.3.scale
# tensor(0.9778)
# model_fp32.conv5_x.0.residual_function.3.zero_point
# tensor(73)
# model_fp32.conv5_x.0.shortcut.0.weight
# model_fp32.conv5_x.0.shortcut.0.bias
# model_fp32.conv5_x.0.shortcut.0.scale
# tensor(0.4337)
# model_fp32.conv5_x.0.shortcut.0.zero_point
# tensor(0)
# model_fp32.conv5_x.1.residual_function.0.weight
# model_fp32.conv5_x.1.residual_function.0.bias
# model_fp32.conv5_x.1.residual_function.0.scale
# tensor(0.6040)
# model_fp32.conv5_x.1.residual_function.0.zero_point
# tensor(0)
# model_fp32.conv5_x.1.residual_function.3.weight
# model_fp32.conv5_x.1.residual_function.3.bias
# model_fp32.conv5_x.1.residual_function.3.scale
# tensor(0.7456)
# model_fp32.conv5_x.1.residual_function.3.zero_point
# tensor(120)
# model_fp32.fc.scale
# tensor(0.3235)
# model_fp32.fc.zero_point
# tensor(56)
# model_fp32.fc._packed_params.dtype
# torch.qint8
# model_fp32.fc._packed_params._packed_params

# %%
#saved layer info
for name in save_list:
    print(name, "  data size:",save_list[name], "byte")
#merge weights
merge_weight_files(save_list)
# Out:
# default_setting   data size: 16 byte
# model_fp32.conv1.0.weight   data size: 9408 byte
# model_fp32.conv1.0.weight_per_channel_scales   data size: 256 byte
# model_fp32.conv1.0.weight_per_channel_zero_points   data size: 256 byte
# model_fp32.conv1.0.bias   data size: 256 byte
# model_fp32.conv2_x.0.residual_function.0.weight   data size: 36864 byte
# model_fp32.conv2_x.0.residual_function.0.weight_per_channel_scales   data size: 256 byte
# model_fp32.conv2_x.0.residual_function.0.weight_per_channel_zero_points   data size: 256 byte
# model_fp32.conv2_x.0.residual_function.0.bias   data size: 256 byte
# model_fp32.conv2_x.0.residual_function.3.weight   data size: 36864 byte
# model_fp32.conv2_x.0.residual_function.3.weight_per_channel_scales   data size: 256 byte
# model_fp32.conv2_x.0.residual_function.3.weight_per_channel_zero_points   data size: 256 byte
# model_fp32.conv2_x.0.residual_function.3.bias   data size: 256 byte
# model_fp32.conv2_x.1.residual_function.0.weight   data size: 36864 byte
# model_fp32.conv2_x.1.residual_function.0.weight_per_channel_scales   data size: 256 byte
# model_fp32.conv2_x.1.residual_function.0.weight_per_channel_zero_points   data size: 256 byte
# model_fp32.conv2_x.1.residual_function.0.bias   data size: 256 byte
# model_fp32.conv2_x.1.residual_function.3.weight   data size: 36864 byte
# model_fp32.conv2_x.1.residual_function.3.weight_per_channel_scales   data size: 256 byte
# model_fp32.conv2_x.1.residual_function.3.weight_per_channel_zero_points   data size: 256 byte
# model_fp32.conv2_x.1.residual_function.3.bias   data size: 256 byte
# model_fp32.conv3_x.0.residual_function.0.weight   data size: 73728 byte
# model_fp32.conv3_x.0.residual_function.0.weight_per_channel_scales   data size: 512 byte
# model_fp32.conv3_x.0.residual_function.0.weight_per_channel_zero_points   data size: 512 byte
# model_fp32.conv3_x.0.residual_function.0.bias   data size: 512 byte
# model_fp32.conv3_x.0.residual_function.3.weight   data size: 147456 byte
# model_fp32.conv3_x.0.residual_function.3.weight_per_channel_scales   data size: 512 byte
# model_fp32.conv3_x.0.residual_function.3.weight_per_channel_zero_points   data size: 512 byte
# model_fp32.conv3_x.0.residual_function.3.bias   data size: 512 byte
# model_fp32.conv3_x.0.shortcut.0.weight   data size: 8192 byte
# model_fp32.conv3_x.0.shortcut.0.weight_per_channel_scales   data size: 512 byte
# model_fp32.conv3_x.0.shortcut.0.weight_per_channel_zero_points   data size: 512 byte
# model_fp32.conv3_x.0.shortcut.0.bias   data size: 512 byte
# model_fp32.conv3_x.1.residual_function.0.weight   data size: 147456 byte
# model_fp32.conv3_x.1.residual_function.0.weight_per_channel_scales   data size: 512 byte
# model_fp32.conv3_x.1.residual_function.0.weight_per_channel_zero_points   data size: 512 byte
# model_fp32.conv3_x.1.residual_function.0.bias   data size: 512 byte
# model_fp32.conv3_x.1.residual_function.3.weight   data size: 147456 byte
# model_fp32.conv3_x.1.residual_function.3.weight_per_channel_scales   data size: 512 byte
# model_fp32.conv3_x.1.residual_function.3.weight_per_channel_zero_points   data size: 512 byte
# model_fp32.conv3_x.1.residual_function.3.bias   data size: 512 byte
# model_fp32.conv4_x.0.residual_function.0.weight   data size: 294912 byte
# model_fp32.conv4_x.0.residual_function.0.weight_per_channel_scales   data size: 1024 byte
# model_fp32.conv4_x.0.residual_function.0.weight_per_channel_zero_points   data size: 1024 byte
# model_fp32.conv4_x.0.residual_function.0.bias   data size: 1024 byte
# model_fp32.conv4_x.0.residual_function.3.weight   data size: 589824 byte
# model_fp32.conv4_x.0.residual_function.3.weight_per_channel_scales   data size: 1024 byte
# model_fp32.conv4_x.0.residual_function.3.weight_per_channel_zero_points   data size: 1024 byte
# model_fp32.conv4_x.0.residual_function.3.bias   data size: 1024 byte
# model_fp32.conv4_x.0.shortcut.0.weight   data size: 32768 byte
# model_fp32.conv4_x.0.shortcut.0.weight_per_channel_scales   data size: 1024 byte
# model_fp32.conv4_x.0.shortcut.0.weight_per_channel_zero_points   data size: 1024 byte
# model_fp32.conv4_x.0.shortcut.0.bias   data size: 1024 byte
# model_fp32.conv4_x.1.residual_function.0.weight   data size: 589824 byte
# model_fp32.conv4_x.1.residual_function.0.weight_per_channel_scales   data size: 1024 byte
# model_fp32.conv4_x.1.residual_function.0.weight_per_channel_zero_points   data size: 1024 byte
# model_fp32.conv4_x.1.residual_function.0.bias   data size: 1024 byte
# model_fp32.conv4_x.1.residual_function.3.weight   data size: 589824 byte
# model_fp32.conv4_x.1.residual_function.3.weight_per_channel_scales   data size: 1024 byte
# model_fp32.conv4_x.1.residual_function.3.weight_per_channel_zero_points   data size: 1024 byte
# model_fp32.conv4_x.1.residual_function.3.bias   data size: 1024 byte
# model_fp32.conv5_x.0.residual_function.0.weight   data size: 1179648 byte
# model_fp32.conv5_x.0.residual_function.0.weight_per_channel_scales   data size: 2048 byte
# model_fp32.conv5_x.0.residual_function.0.weight_per_channel_zero_points   data size: 2048 byte
# model_fp32.conv5_x.0.residual_function.0.bias   data size: 2048 byte
# model_fp32.conv5_x.0.residual_function.3.weight   data size: 2359296 byte
# model_fp32.conv5_x.0.residual_function.3.weight_per_channel_scales   data size: 2048 byte
# model_fp32.conv5_x.0.residual_function.3.weight_per_channel_zero_points   data size: 2048 byte
# model_fp32.conv5_x.0.residual_function.3.bias   data size: 2048 byte
# model_fp32.conv5_x.0.shortcut.0.weight   data size: 131072 byte
# model_fp32.conv5_x.0.shortcut.0.weight_per_channel_scales   data size: 2048 byte
# model_fp32.conv5_x.0.shortcut.0.weight_per_channel_zero_points   data size: 2048 byte
# model_fp32.conv5_x.0.shortcut.0.bias   data size: 2048 byte
# model_fp32.conv5_x.1.residual_function.0.weight   data size: 2359296 byte
# model_fp32.conv5_x.1.residual_function.0.weight_per_channel_scales   data size: 2048 byte
# model_fp32.conv5_x.1.residual_function.0.weight_per_channel_zero_points   data size: 2048 byte
# model_fp32.conv5_x.1.residual_function.0.bias   data size: 2048 byte
# model_fp32.conv5_x.1.residual_function.3.weight   data size: 2359296 byte
# model_fp32.conv5_x.1.residual_function.3.weight_per_channel_scales   data size: 2048 byte
# model_fp32.conv5_x.1.residual_function.3.weight_per_channel_zero_points   data size: 2048 byte
# model_fp32.conv5_x.1.residual_function.3.bias   data size: 2048 byte
# model_fp32.fc._packed_params._packed_params   data size: 5120 byte
# model_fp32.fc._packed_params._packed_params_per_channel_scales   data size: 40 byte
# model_fp32.fc._packed_params._packed_params_per_channel_zero_points   data size: 40 byte
# model_fp32.fc._packed_params._packed_params_bias   data size: 40 byte
